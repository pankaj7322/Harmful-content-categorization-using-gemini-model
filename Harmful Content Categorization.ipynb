# %%
import pandas as pd
import google.generativeai as genai
from google.generativeai.types import HarmCategory, HarmBlockThreshold

api_key = "AIzaSyDmf1l9sIE1mGct61wGZc83SHTrC0bSoCU"
genai.configure(api_key = api_key)

category= ["You are an ignorant fool.",
            "She's a complete moron.",
            "A transgender man is referred to as “she” in an email"
            "A non-binary person is referred to as “it” by a coworker",
            "He's such a loser.",
            "A female banker is passed over for a promotion because she’s not “leader material"
            "They're utter imbeciles.",
            "A male nurse faces harassment for having what’s perceived as a woman’s job",
            "Direct threats of intent to inflict harm",
            "Isolating or excluding the victim or denying the victim’s presence",
            "we dont want you here anyways",
            "i kill you"
        
          ]

text = " ".join(category)

prompt = f"""
            categorised the below sentence one by one eg sentence, category, target, reason.
            
         """
model = genai.GenerativeModel(model_name='gemini-pro')
response = model.generate_content(
    [prompt, text],
    safety_settings={
        HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE
    }
)
print(response.text)
# try:
#     print(response.text)
# except ValueError:
#   # If the response doesn't contain text, check if the prompt was blocked.
#   print(response.prompt_feedback)
#   # Also check the finish reason to see if the response was blocked.
#   print(response.candidates[0].finish_reason)
#   # If the finish reason was SAFETY, the safety ratings have more details.
#   print(response.candidates[0].safety_ratings)
    
    


text = response.text
# Splitting the text into individual sentences
data = text.split("\n")

# Extracting information from each string
sentences = []
categories = []
targets = []
reasons = []

counter = 0
for i in range(0, len(data)):
    words = data[i].split(":")
    if words[0].strip("**") == 'Sentence':
        sentences.append(words[1].strip("**"))
    elif words[0].strip("**") == 'Category':
        categories.append(words[1].strip("**"))
    elif words[0].strip("**") == 'Target':
        targets.append(words[1].strip("**"))
    elif words[0].strip("**") == 'Reason':
        reasons.append(words[1].strip("**"))


            
# Creating a dataframe from the extracted information
df = pd.DataFrame({
    "Sentence": sentences,
    "Category": categories,
    "Target": targets,
    "Reason": reasons
})
df
# Out:
# **Sentence:** You are an ignorant fool.
# **Category:** Insult
# **Target:** You
# **Reason:** The speaker is expressing their opinion that the person they are speaking to is stupid and uninformed.
#
# **Sentence:** She's a complete moron.
# **Category:** Insult
# **Target:** She
# **Reason:** The speaker is expressing their opinion that the person they are speaking to is stupid and foolish.
#
# **Sentence:**  A transgender man is referred to as “she” in an email
# **Category:** Misgendering
# **Target:** A transgender man
# **Reason:** The person sending the email is using the wrong pronoun to refer to the transgender man.
#
# **Sentence:**A non-binary person is referred to as “it” by a coworker
# **Category:** Misgendering
# **Target:** A non-binary person
# **Reason:** The coworker is using the wrong pronoun to refer to the non-binary person.
#
# **Sentence:** He's such a loser.
# **Category:** Insult
# **Target:** He
# ...
